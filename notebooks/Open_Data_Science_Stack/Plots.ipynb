# %% [markdown]
# # MATPLOTLIB
#
# ### [Documentacao Oficial / https://matplotlib.org ](https://matplotlib.org)

# %%
import matplotlib as mlp
import matplotlib.pyplot as plt

# %%
plt.plot([1,3,5],[2,4,6])
plt.show()

# %%
plt.plot([1,3,5],[2,4,6], label='Serie de dados')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.legend()
plt.title('Grafico de Exemplo')
plt.show()
